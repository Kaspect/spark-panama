# %%
import json
import itertools
import numpy as np
import pandas as pd
from collections import Counter

# %%
with open("data/ner_overlap.json") as y:
    ner_source = json.load(y)

# %%
ner_result_lists = ner_source['response']['docs']

# %%
LoL = [set(x['ner_names']) for x in ner_result_lists]

# %%
LoL[8]
# Out:
# {'1986',
#  'ABC',
#  'Affiliated',
#  'Company',
#  'Control Act',
#  'GROBID',
#  'Please Explain',
#  'Relocate',
#  'TEI',
#  'United States',
#  'Walt Disney'}

# %%
corpus_with_duplicates = [x for x in itertools.chain(*LoL)]

# %%
most_common_entities = Counter(corpus_with_duplicates).most_common(10)

# %%
most_common_strings = [x[0] for x in most_common_entities]

# %%
def string_is_in_the_ner_names(string, ner_names_list):
    if string in ner_names_list:
        return True
    else:
        return False

# %%
ner_with_sorry = [x['id'] for x in ner_result_lists if string_is_in_the_ner_names("Sorry", x['ner_names'])]

# %%
def does_this_url_have_this_ner(url, string, ner_result_lists):
    file_metadata = [x for x in ner_result_lists if x['id']=='http://polar.usc.edu/hh1337'][0]
#     print(file_metadata)
    return string in file_metadata['ner_names']

# %%
does_this_url_have_this_ner('http://polar.usc.edu/hh1337', 'last year', ner_result_lists)
# Out:
# True

# %%
sorry_df = pd.DataFrame(ner_with_sorry)

# %%
sorry_df['e'] = pd.Series(np.ones(len(sorry_df[0])), index=sorry_df.index)

# %%
sorry_df.head()
# Out:
#                              0  e
# 0      http://polar.usc.edu/2s  1
# 1      http://polar.usc.edu/2p  1
# 2  http://polar.usc.edu/hh1337  1
# 3  http://polar.usc.edu/hh1343  1
# 4  http://polar.usc.edu/hh1344  1

# %%
df = pd.DataFrame(ner_result_lists).head()

# %%
# ner_result_lists

# %%
def map_string_occurrence_to_vector(vector, string, ner_result_lists):
    """return 0 if there was no NER match, 1 if there was a match"""
    return [does_this_url_have_this_ner(x['id'],string, ner_result_lists) for x in ner_result_lists]

# %%
map_string_occurrence_to_vector(all_ids,"Mexico",ner_result_lists)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-60005979f918> in <module>()
# ----> 1 map_string_occurrence_to_vector(all_ids,"Mexico",ner_result_lists)
#
# NameError: name 'all_ids' is not defined

# %%
all_ids = [x['id'] for x in ner_result_lists]

# %%
all_ids
# Out:
# ['http://polar.usc.edu/ia',
#  'http://polar.usc.edu/ib',
#  'http://polar.usc.edu/6f',
#  'http://polar.usc.edu/6g',
#  'http://polar.usc.edu/6i',
#  'http://polar.usc.edu/hk',
#  'http://polar.usc.edu/hl',
#  'http://polar.usc.edu/hn',
#  'http://polar.usc.edu/hm',
#  'http://polar.usc.edu/3x',
#  'http://polar.usc.edu/3y',
#  'http://polar.usc.edu/3w',
#  'http://polar.usc.edu/4b',
#  'http://polar.usc.edu/4d',
#  'http://polar.usc.edu/4c',
#  'http://polar.usc.edu/49',
#  'http://polar.usc.edu/48',
#  'http://polar.usc.edu/4e',
#  'http://polar.usc.edu/4a',
#  'http://polar.usc.edu/4f',
#  'http://polar.usc.edu/4g',
#  'http://polar.usc.edu/4o',
#  'http://polar.usc.edu/4p',
#  'http://polar.usc.edu/4h',
#  'http://polar.usc.edu/4k',
#  'http://polar.usc.edu/4l',
#  'http://polar.usc.edu/4j',
#  'http://polar.usc.edu/4i',
#  'http://polar.usc.edu/4m',
#  'http://polar.usc.edu/4n',
#  'http://polar.usc.edu/56',
#  'http://polar.usc.edu/53',
#  'http://polar.usc.edu/50',
#  'http://polar.usc.edu/55',
#  'http://polar.usc.edu/52',
#  'http://polar.usc.edu/51',
#  'http://polar.usc.edu/4z',
#  'http://polar.usc.edu/57',
#  'http://polar.usc.edu/54',
#  'http://polar.usc.edu/5j',
#  'http://polar.usc.edu/5k',
#  'http://polar.usc.edu/5o',
#  'http://polar.usc.edu/5i',
#  'http://polar.usc.edu/5m',
#  'http://polar.usc.edu/5h',
#  'http://polar.usc.edu/5l',
#  'http://polar.usc.edu/5n',
#  'http://polar.usc.edu/5p',
#  'http://polar.usc.edu/62',
#  'http://polar.usc.edu/60',
#  'http://polar.usc.edu/61',
#  'http://polar.usc.edu/63',
#  'http://polar.usc.edu/66',
#  'http://polar.usc.edu/64',
#  'http://polar.usc.edu/67',
#  'http://polar.usc.edu/65',
#  'http://polar.usc.edu/5z',
#  'http://polar.usc.edu/hj',
#  'http://polar.usc.edu/hc',
#  'http://polar.usc.edu/hh',
#  'http://polar.usc.edu/hg',
#  'http://polar.usc.edu/hi',
#  'http://polar.usc.edu/hf',
#  'http://polar.usc.edu/hd',
#  'http://polar.usc.edu/he',
#  'http://polar.usc.edu/41',
#  'http://polar.usc.edu/42',
#  'http://polar.usc.edu/47',
#  'http://polar.usc.edu/3z',
#  'http://polar.usc.edu/46',
#  'http://polar.usc.edu/43',
#  'http://polar.usc.edu/45',
#  'http://polar.usc.edu/40',
#  'http://polar.usc.edu/44',
#  'http://polar.usc.edu/4y',
#  'http://polar.usc.edu/4v',
#  'http://polar.usc.edu/4w',
#  'http://polar.usc.edu/4q',
#  'http://polar.usc.edu/4r',
#  'http://polar.usc.edu/4s',
#  'http://polar.usc.edu/4x',
#  'http://polar.usc.edu/4u',
#  'http://polar.usc.edu/4t',
#  'http://polar.usc.edu/5e',
#  'http://polar.usc.edu/5g',
#  'http://polar.usc.edu/5a',
#  'http://polar.usc.edu/5f',
#  'http://polar.usc.edu/59',
#  'http://polar.usc.edu/5c',
#  'http://polar.usc.edu/58',
#  'http://polar.usc.edu/5b',
#  'http://polar.usc.edu/5d',
#  'http://polar.usc.edu/5u',
#  'http://polar.usc.edu/5w',
#  'http://polar.usc.edu/5s',
#  'http://polar.usc.edu/5r',
#  'http://polar.usc.edu/5y',
#  'http://polar.usc.edu/5x',
#  'http://polar.usc.edu/5v',
#  'http://polar.usc.edu/5t',
#  'http://polar.usc.edu/5q',
#  'http://polar.usc.edu/68',
#  'http://polar.usc.edu/69',
#  'http://polar.usc.edu/ax',
#  'http://polar.usc.edu/6c',
#  'http://polar.usc.edu/aw',
#  'http://polar.usc.edu/al',
#  'http://polar.usc.edu/b2',
#  'http://polar.usc.edu/6b',
#  'http://polar.usc.edu/1t',
#  'http://polar.usc.edu/1z',
#  'http://polar.usc.edu/1x',
#  'http://polar.usc.edu/1u',
#  'http://polar.usc.edu/1y',
#  'http://polar.usc.edu/1s',
#  'http://polar.usc.edu/1q',
#  'http://polar.usc.edu/1r',
#  'http://polar.usc.edu/1w',
#  'http://polar.usc.edu/1v',
#  'http://polar.usc.edu/25',
#  'http://polar.usc.edu/20',
#  'http://polar.usc.edu/27',
#  'http://polar.usc.edu/23',
#  'http://polar.usc.edu/2d',
#  'http://polar.usc.edu/2c',
#  'http://polar.usc.edu/2b',
#  'http://polar.usc.edu/2a',
#  'http://polar.usc.edu/29',
#  'http://polar.usc.edu/37',
#  'http://polar.usc.edu/32',
#  'http://polar.usc.edu/31',
#  'http://polar.usc.edu/34',
#  'http://polar.usc.edu/38',
#  'http://polar.usc.edu/35',
#  'http://polar.usc.edu/30',
#  'http://polar.usc.edu/33',
#  'http://polar.usc.edu/36',
#  'http://polar.usc.edu/3r',
#  'http://polar.usc.edu/3s',
#  'http://polar.usc.edu/3t',
#  'http://polar.usc.edu/3u',
#  'http://polar.usc.edu/gq',
#  'http://polar.usc.edu/gr',
#  'http://polar.usc.edu/3v',
#  'http://polar.usc.edu/gt',
#  'http://polar.usc.edu/gs',
#  'http://polar.usc.edu/6j',
#  'http://polar.usc.edu/1a',
#  'http://polar.usc.edu/1c',
#  'http://polar.usc.edu/18',
#  'http://polar.usc.edu/1d',
#  'http://polar.usc.edu/1e',
#  'http://polar.usc.edu/1g',
#  'http://polar.usc.edu/19',
#  'http://polar.usc.edu/1b',
#  'http://polar.usc.edu/1f',
#  'http://polar.usc.edu/2v',
#  'http://polar.usc.edu/2w',
#  'http://polar.usc.edu/2t',
#  'http://polar.usc.edu/2z',
#  'http://polar.usc.edu/2x',
#  'http://polar.usc.edu/2y',
#  'http://polar.usc.edu/2u',
#  'http://polar.usc.edu/2s',
#  'http://polar.usc.edu/2r',
#  'http://polar.usc.edu/3p',
#  'http://polar.usc.edu/3n',
#  'http://polar.usc.edu/3o',
#  'http://polar.usc.edu/3j',
#  'http://polar.usc.edu/3q',
#  'http://polar.usc.edu/3l',
#  'http://polar.usc.edu/3k',
#  'http://polar.usc.edu/3i',
#  'http://polar.usc.edu/3m',
#  'http://polar.usc.edu/15',
#  'http://polar.usc.edu/14',
#  'http://polar.usc.edu/17',
#  'http://polar.usc.edu/16',
#  'http://polar.usc.edu/1i',
#  'http://polar.usc.edu/1k',
#  'http://polar.usc.edu/1p',
#  'http://polar.usc.edu/1n',
#  'http://polar.usc.edu/1m',
#  'http://polar.usc.edu/1h',
#  'http://polar.usc.edu/1l',
#  'http://polar.usc.edu/1j',
#  'http://polar.usc.edu/1o',
#  'http://polar.usc.edu/2i',
#  'http://polar.usc.edu/2k',
#  'http://polar.usc.edu/2j',
#  'http://polar.usc.edu/2p',
#  'http://polar.usc.edu/2q',
#  'http://polar.usc.edu/2m',
#  'http://polar.usc.edu/2o',
#  'http://polar.usc.edu/2n',
#  'http://polar.usc.edu/2l',
#  'http://polar.usc.edu/3d',
#  'http://polar.usc.edu/39',
#  'http://polar.usc.edu/3f',
#  'http://polar.usc.edu/3c',
#  'http://polar.usc.edu/3e',
#  'http://polar.usc.edu/3a',
#  'http://polar.usc.edu/3g',
#  'http://polar.usc.edu/3b',
#  'http://polar.usc.edu/3h',
#  'http://polar.usc.edu/gx',
#  'http://polar.usc.edu/gz',
#  'http://polar.usc.edu/gy',
#  'http://polar.usc.edu/gv',
#  'http://polar.usc.edu/gu',
#  'http://polar.usc.edu/ha',
#  'http://polar.usc.edu/e0',
#  'http://polar.usc.edu/dt',
#  'http://polar.usc.edu/dv',
#  'http://polar.usc.edu/dw',
#  'http://polar.usc.edu/dz',
#  'http://polar.usc.edu/dx',
#  'http://polar.usc.edu/c9',
#  'http://polar.usc.edu/dy',
#  'http://polar.usc.edu/6a',
#  'http://polar.usc.edu/ck',
#  'http://polar.usc.edu/e4',
#  'http://polar.usc.edu/e1',
#  'http://polar.usc.edu/e3',
#  'http://polar.usc.edu/e9',
#  'http://polar.usc.edu/e6',
#  'http://polar.usc.edu/e2',
#  'http://polar.usc.edu/e5',
#  'http://polar.usc.edu/e8',
#  'http://polar.usc.edu/e7',
#  'http://polar.usc.edu/ed',
#  'http://polar.usc.edu/ea',
#  'http://polar.usc.edu/ef',
#  'http://polar.usc.edu/eg',
#  'http://polar.usc.edu/ec',
#  'http://polar.usc.edu/ee',
#  'http://polar.usc.edu/eh',
#  'http://polar.usc.edu/ei',
#  'http://polar.usc.edu/eb',
#  'http://polar.usc.edu/ek',
#  'http://polar.usc.edu/en',
#  'http://polar.usc.edu/em',
#  'http://polar.usc.edu/eq',
#  'http://polar.usc.edu/ep',
#  'http://polar.usc.edu/ej',
#  'http://polar.usc.edu/er',
#  'http://polar.usc.edu/el',
#  'http://polar.usc.edu/eo',
#  'http://polar.usc.edu/f0',
#  'http://polar.usc.edu/ex',
#  'http://polar.usc.edu/eu',
#  'http://polar.usc.edu/ez',
#  'http://polar.usc.edu/ey',
#  'http://polar.usc.edu/ew',
#  'http://polar.usc.edu/et',
#  'http://polar.usc.edu/es',
#  'http://polar.usc.edu/ev',
#  'http://polar.usc.edu/f1',
#  'http://polar.usc.edu/f8',
#  'http://polar.usc.edu/fa',
#  'http://polar.usc.edu/f6',
#  'http://polar.usc.edu/f3',
#  'http://polar.usc.edu/f7',
#  'http://polar.usc.edu/f9',
#  'http://polar.usc.edu/f5',
#  'http://polar.usc.edu/f4',
#  'http://polar.usc.edu/fb',
#  'http://polar.usc.edu/fg',
#  'http://polar.usc.edu/fj',
#  'http://polar.usc.edu/fe',
#  'http://polar.usc.edu/ff',
#  'http://polar.usc.edu/fd',
#  'http://polar.usc.edu/fh',
#  'http://polar.usc.edu/fc',
#  'http://polar.usc.edu/fi',
#  'http://polar.usc.edu/fr',
#  'http://polar.usc.edu/fk',
#  'http://polar.usc.edu/fp',
#  'http://polar.usc.edu/fl',
#  'http://polar.usc.edu/fq',
#  'http://polar.usc.edu/fs',
#  'http://polar.usc.edu/fn',
#  'http://polar.usc.edu/fo',
#  'http://polar.usc.edu/fm',
#  'http://polar.usc.edu/fy',
#  'http://polar.usc.edu/fw',
#  'http://polar.usc.edu/fv',
#  'http://polar.usc.edu/fu',
#  'http://polar.usc.edu/ft',
#  'http://polar.usc.edu/fz',
#  'http://polar.usc.edu/g1',
#  'http://polar.usc.edu/fx',
#  'http://polar.usc.edu/g0',
#  'http://polar.usc.edu/ga',
#  'http://polar.usc.edu/g3',
#  'http://polar.usc.edu/g6',
#  'http://polar.usc.edu/g2',
#  'http://polar.usc.edu/g4',
#  'http://polar.usc.edu/g9',
#  'http://polar.usc.edu/g8',
#  'http://polar.usc.edu/g5',
#  'http://polar.usc.edu/g7',
#  'http://polar.usc.edu/gh',
#  'http://polar.usc.edu/gb',
#  'http://polar.usc.edu/ge',
#  'http://polar.usc.edu/gf',
#  'http://polar.usc.edu/gc',
#  'http://polar.usc.edu/gd',
#  'http://polar.usc.edu/gj',
#  'http://polar.usc.edu/gi',
#  'http://polar.usc.edu/gg',
#  'http://polar.usc.edu/go',
#  'http://polar.usc.edu/gk',
#  'http://polar.usc.edu/gp',
#  'http://polar.usc.edu/gl',
#  'http://polar.usc.edu/6p',
#  'http://polar.usc.edu/gn',
#  'http://polar.usc.edu/6n',
#  'http://polar.usc.edu/6o',
#  'http://polar.usc.edu/6y',
#  'http://polar.usc.edu/6u',
#  'http://polar.usc.edu/j',
#  'http://polar.usc.edu/k',
#  'http://polar.usc.edu/o',
#  'http://polar.usc.edu/u',
#  'http://polar.usc.edu/s',
#  'http://polar.usc.edu/q',
#  'http://polar.usc.edu/p',
#  'http://polar.usc.edu/t',
#  'http://polar.usc.edu/n',
#  'http://polar.usc.edu/m',
#  'http://polar.usc.edu/l',
#  'http://polar.usc.edu/r',
#  'http://polar.usc.edu/70',
#  'http://polar.usc.edu/73',
#  'http://polar.usc.edu/78',
#  'http://polar.usc.edu/7l',
#  'http://polar.usc.edu/7k',
#  'http://polar.usc.edu/7m',
#  'http://polar.usc.edu/7i',
#  'http://polar.usc.edu/7j',
#  'http://polar.usc.edu/7x',
#  'http://polar.usc.edu/91',
#  'http://polar.usc.edu/8f',
#  'http://polar.usc.edu/86',
#  'http://polar.usc.edu/8n',
#  'http://polar.usc.edu/8h',
#  'http://polar.usc.edu/8u',
#  'http://polar.usc.edu/8v',
#  'http://polar.usc.edu/8x',
#  'http://polar.usc.edu/8y',
#  'http://polar.usc.edu/8w',
#  'http://polar.usc.edu/8t',
#  'http://polar.usc.edu/80',
#  'http://polar.usc.edu/87',
#  'http://polar.usc.edu/7w',
#  'http://polar.usc.edu/84',
#  'http://polar.usc.edu/95',
#  'http://polar.usc.edu/90',
#  'http://polar.usc.edu/8z',
#  'http://polar.usc.edu/9t',
#  'http://polar.usc.edu/9q',
#  'http://polar.usc.edu/9p',
#  'http://polar.usc.edu/9r',
#  'http://polar.usc.edu/9u',
#  'http://polar.usc.edu/9o',
#  'http://polar.usc.edu/9v',
#  'http://polar.usc.edu/9w',
#  'http://polar.usc.edu/av',
#  'http://polar.usc.edu/au',
#  'http://polar.usc.edu/ay',
#  'http://polar.usc.edu/as',
#  'http://polar.usc.edu/b0',
#  'http://polar.usc.edu/at',
#  'http://polar.usc.edu/b1',
#  'http://polar.usc.edu/az',
#  'http://polar.usc.edu/ar',
#  'http://polar.usc.edu/v',
#  'http://polar.usc.edu/y',
#  'http://polar.usc.edu/w',
#  'http://polar.usc.edu/x',
#  'http://polar.usc.edu/bo',
#  'http://polar.usc.edu/bv',
#  'http://polar.usc.edu/c0',
#  'http://polar.usc.edu/11',
#  'http://polar.usc.edu/13',
#  'http://polar.usc.edu/12',
#  'http://polar.usc.edu/ca',
#  'http://polar.usc.edu/cd',
#  'http://polar.usc.edu/ce',
#  'http://polar.usc.edu/cb',
#  'http://polar.usc.edu/cg',
#  'http://polar.usc.edu/cn',
#  'http://polar.usc.edu/co',
#  'http://polar.usc.edu/cm',
#  'http://polar.usc.edu/cf',
#  'http://polar.usc.edu/cp',
#  'http://polar.usc.edu/cu',
#  'http://polar.usc.edu/cq',
#  'http://polar.usc.edu/cr',
#  'http://polar.usc.edu/cx',
#  'http://polar.usc.edu/d6',
#  'http://polar.usc.edu/cy',
#  'http://polar.usc.edu/d5',
#  'http://polar.usc.edu/d2',
#  'http://polar.usc.edu/d3',
#  'http://polar.usc.edu/df',
#  'http://polar.usc.edu/d9',
#  'http://polar.usc.edu/de',
#  'http://polar.usc.edu/dc',
#  'http://polar.usc.edu/da',
#  'http://polar.usc.edu/dn',
#  'http://polar.usc.edu/dg',
#  'http://polar.usc.edu/dk',
#  'http://polar.usc.edu/do',
#  'http://polar.usc.edu/dh',
#  'http://polar.usc.edu/hq',
#  'http://polar.usc.edu/ho',
#  'http://polar.usc.edu/hp',
#  'http://polar.usc.edu/hr',
#  'http://polar.usc.edu/dp',
#  'http://polar.usc.edu/ds',
#  'http://polar.usc.edu/dq',
#  'http://polar.usc.edu/dr',
#  'http://polar.usc.edu/x5',
#  'http://polar.usc.edu/x6',
#  'http://polar.usc.edu/i2',
#  'http://polar.usc.edu/i5',
#  'http://polar.usc.edu/i4',
#  'http://polar.usc.edu/i3',
#  'http://polar.usc.edu/i1',
#  'http://polar.usc.edu/i6',
#  'http://polar.usc.edu/92',
#  'http://polar.usc.edu/98',
#  'http://polar.usc.edu/97',
#  'http://polar.usc.edu/9j',
#  'http://polar.usc.edu/9k',
#  'http://polar.usc.edu/9i',
#  'http://polar.usc.edu/9l',
#  'http://polar.usc.edu/9m',
#  'http://polar.usc.edu/9n',
#  'http://polar.usc.edu/9x',
#  'http://polar.usc.edu/9y',
#  'http://polar.usc.edu/9z',
#  'http://polar.usc.edu/ag',
#  'http://polar.usc.edu/a9',
#  'http://polar.usc.edu/am',
#  'http://polar.usc.edu/an',
#  'http://polar.usc.edu/aq',
#  'http://polar.usc.edu/ap',
#  'http://polar.usc.edu/ak',
#  'http://polar.usc.edu/ao',
#  'http://polar.usc.edu/b3',
#  'http://polar.usc.edu/b9',
#  'http://polar.usc.edu/b5',
#  'http://polar.usc.edu/b4',
#  'http://polar.usc.edu/b6',
#  'http://polar.usc.edu/bf',
#  'http://polar.usc.edu/bk',
#  'http://polar.usc.edu/bh',
#  'http://polar.usc.edu/i0',
#  'http://polar.usc.edu/ht',
#  'http://polar.usc.edu/hs',
#  'http://polar.usc.edu/hy',
#  'http://polar.usc.edu/hu',
#  'http://polar.usc.edu/hx',
#  'http://polar.usc.edu/hw',
#  'http://polar.usc.edu/x7',
#  'http://polar.usc.edu/10o',
#  'http://polar.usc.edu/10m',
#  'http://polar.usc.edu/10k',
#  'http://polar.usc.edu/10j',
#  'http://polar.usc.edu/111',
#  'http://polar.usc.edu/116',
#  'http://polar.usc.edu/10z',
#  'http://polar.usc.edu/117',
#  'http://polar.usc.edu/115',
#  'http://polar.usc.edu/113',
#  'http://polar.usc.edu/112',
#  'http://polar.usc.edu/110',
#  'http://polar.usc.edu/114',
#  'http://polar.usc.edu/11v',
#  'http://polar.usc.edu/11w',
#  'http://polar.usc.edu/11r',
#  'http://polar.usc.edu/11u',
#  'http://polar.usc.edu/11s',
#  'http://polar.usc.edu/11x',
#  'http://polar.usc.edu/11q',
#  'http://polar.usc.edu/11t',
#  'http://polar.usc.edu/12n',
#  'http://polar.usc.edu/12l',
#  'http://polar.usc.edu/12i',
#  'http://polar.usc.edu/12m',
#  'http://polar.usc.edu/12o',
#  'http://polar.usc.edu/12p',
#  'http://polar.usc.edu/12j',
#  'http://polar.usc.edu/12h',
#  'http://polar.usc.edu/12z',
#  'http://polar.usc.edu/135',
#  'http://polar.usc.edu/132',
#  'http://polar.usc.edu/137',
#  'http://polar.usc.edu/13b',
#  'http://polar.usc.edu/139',
#  'http://polar.usc.edu/138',
#  'http://polar.usc.edu/13a',
#  'http://polar.usc.edu/13g',
#  'http://polar.usc.edu/13d',
#  'http://polar.usc.edu/13c',
#  'http://polar.usc.edu/13f',
#  'http://polar.usc.edu/13e',
#  'http://polar.usc.edu/h86',
#  'http://polar.usc.edu/h88',
#  'http://polar.usc.edu/h83',
#  'http://polar.usc.edu/h85',
#  'http://polar.usc.edu/h89',
#  'http://polar.usc.edu/h87',
#  'http://polar.usc.edu/h90',
#  'http://polar.usc.edu/h91',
#  'http://polar.usc.edu/h84',
#  'http://polar.usc.edu/10c',
#  'http://polar.usc.edu/10d',
#  'http://polar.usc.edu/10b',
#  'http://polar.usc.edu/yx',
#  'http://polar.usc.edu/yw',
#  'http://polar.usc.edu/zd',
#  'http://polar.usc.edu/ze',
#  'http://polar.usc.edu/zl',
#  'http://polar.usc.edu/zm',
#  'http://polar.usc.edu/zk',
#  'http://polar.usc.edu/zo',
#  'http://polar.usc.edu/zq',
#  'http://polar.usc.edu/zp',
#  'http://polar.usc.edu/zs',
#  'http://polar.usc.edu/zr',
#  'http://polar.usc.edu/zt',
#  'http://polar.usc.edu/101',
#  'http://polar.usc.edu/zz',
#  'http://polar.usc.edu/zy',
#  'http://polar.usc.edu/zx',
#  'http://polar.usc.edu/100',
#  'http://polar.usc.edu/104',
#  'http://polar.usc.edu/10a',
#  'http://polar.usc.edu/107',
#  'http://polar.usc.edu/102',
#  'http://polar.usc.edu/105',
#  'http://polar.usc.edu/108',
#  'http://polar.usc.edu/106',
#  'http://polar.usc.edu/109',
#  'http://polar.usc.edu/103',
#  'http://polar.usc.edu/h96',
#  'http://polar.usc.edu/h93',
#  'http://polar.usc.edu/h98',
#  'http://polar.usc.edu/h97',
#  'http://polar.usc.edu/h95',
#  'http://polar.usc.edu/h100',
#  'http://polar.usc.edu/h92',
#  'http://polar.usc.edu/h94',
#  'http://polar.usc.edu/h99',
#  'http://polar.usc.edu/h128',
#  'http://polar.usc.edu/h132',
#  'http://polar.usc.edu/h131',
#  'http://polar.usc.edu/h133',
#  'http://polar.usc.edu/h134',
#  'http://polar.usc.edu/h130',
#  'http://polar.usc.edu/h135',
#  'http://polar.usc.edu/h136',
#  'http://polar.usc.edu/h129',
#  'http://polar.usc.edu/10w',
#  'http://polar.usc.edu/11a',
#  'http://polar.usc.edu/11e',
#  'http://polar.usc.edu/11f',
#  'http://polar.usc.edu/119',
#  'http://polar.usc.edu/11d',
#  'http://polar.usc.edu/11g',
#  'http://polar.usc.edu/11c',
#  'http://polar.usc.edu/118',
#  'http://polar.usc.edu/123',
#  'http://polar.usc.edu/124',
#  'http://polar.usc.edu/121',
#  'http://polar.usc.edu/120',
#  'http://polar.usc.edu/126',
#  'http://polar.usc.edu/122',
#  'http://polar.usc.edu/125',
#  'http://polar.usc.edu/11z',
#  'http://polar.usc.edu/13j',
#  'http://polar.usc.edu/13k',
#  'http://polar.usc.edu/13l',
#  'http://polar.usc.edu/13n',
#  'http://polar.usc.edu/h1',
#  'http://polar.usc.edu/13i',
#  'http://polar.usc.edu/13m',
#  'http://polar.usc.edu/13h',
#  'http://polar.usc.edu/h12',
#  'http://polar.usc.edu/h17',
#  'http://polar.usc.edu/h19',
#  'http://polar.usc.edu/h18',
#  'http://polar.usc.edu/h14',
#  'http://polar.usc.edu/h15',
#  'http://polar.usc.edu/h13',
#  'http://polar.usc.edu/h16',
#  'http://polar.usc.edu/h11',
#  'http://polar.usc.edu/h24',
#  'http://polar.usc.edu/h25',
#  'http://polar.usc.edu/h27',
#  'http://polar.usc.edu/h21',
#  'http://polar.usc.edu/h26',
#  'http://polar.usc.edu/h20',
#  'http://polar.usc.edu/h22',
#  'http://polar.usc.edu/h23',
#  'http://polar.usc.edu/h28',
#  'http://polar.usc.edu/h34',
#  'http://polar.usc.edu/h36',
#  'http://polar.usc.edu/h30',
#  'http://polar.usc.edu/h33',
#  'http://polar.usc.edu/h29',
#  'http://polar.usc.edu/h32',
#  'http://polar.usc.edu/h31',
#  'http://polar.usc.edu/h37',
#  'http://polar.usc.edu/h35',
#  'http://polar.usc.edu/h40',
#  'http://polar.usc.edu/h38',
#  'http://polar.usc.edu/h39',
#  'http://polar.usc.edu/h45',
#  'http://polar.usc.edu/h46',
#  'http://polar.usc.edu/h41',
#  'http://polar.usc.edu/h42',
#  'http://polar.usc.edu/h43',
#  'http://polar.usc.edu/h44',
#  'http://polar.usc.edu/h52',
#  'http://polar.usc.edu/h55',
#  'http://polar.usc.edu/h51',
#  'http://polar.usc.edu/h48',
#  'http://polar.usc.edu/h49',
#  'http://polar.usc.edu/h53',
#  'http://polar.usc.edu/h50',
#  'http://polar.usc.edu/h54',
#  'http://polar.usc.edu/h47',
#  'http://polar.usc.edu/h60',
#  'http://polar.usc.edu/h64',
#  'http://polar.usc.edu/h58',
#  'http://polar.usc.edu/h61',
#  'http://polar.usc.edu/h63',
#  'http://polar.usc.edu/h56',
#  'http://polar.usc.edu/h59',
#  'http://polar.usc.edu/h57',
#  'http://polar.usc.edu/h62',
#  'http://polar.usc.edu/h78',
#  'http://polar.usc.edu/h79',
#  'http://polar.usc.edu/h76',
#  'http://polar.usc.edu/h80',
#  'http://polar.usc.edu/h77',
#  'http://polar.usc.edu/h75',
#  'http://polar.usc.edu/h74',
#  'http://polar.usc.edu/h81',
#  'http://polar.usc.edu/h82',
#  'http://polar.usc.edu/h102',
#  'http://polar.usc.edu/h107',
#  'http://polar.usc.edu/h106',
#  'http://polar.usc.edu/h105',
#  'http://polar.usc.edu/h109',
#  'http://polar.usc.edu/h108',
#  'http://polar.usc.edu/h101',
#  'http://polar.usc.edu/h103',
#  'http://polar.usc.edu/h104',
#  'http://polar.usc.edu/h138',
#  'http://polar.usc.edu/h141',
#  'http://polar.usc.edu/h140',
#  'http://polar.usc.edu/h139',
#  'http://polar.usc.edu/h142',
#  'http://polar.usc.edu/h137',
#  'http://polar.usc.edu/10t',
#  'http://polar.usc.edu/10s',
#  'http://polar.usc.edu/10v',
#  'http://polar.usc.edu/10u',
#  'http://polar.usc.edu/10x',
#  'http://polar.usc.edu/10y',
#  'http://polar.usc.edu/10r',
#  'http://polar.usc.edu/10p',
#  'http://polar.usc.edu/10q',
#  'http://polar.usc.edu/11l',
#  'http://polar.usc.edu/11p',
#  'http://polar.usc.edu/11j',
#  'http://polar.usc.edu/11h',
#  'http://polar.usc.edu/11o',
#  'http://polar.usc.edu/11m',
#  'http://polar.usc.edu/11n',
#  'http://polar.usc.edu/11i',
#  'http://polar.usc.edu/11k',
#  'http://polar.usc.edu/12f',
#  'http://polar.usc.edu/128',
#  'http://polar.usc.edu/12a',
#  'http://polar.usc.edu/12d',
#  'http://polar.usc.edu/12b',
#  'http://polar.usc.edu/129',
#  'http://polar.usc.edu/12g',
#  'http://polar.usc.edu/12t',
#  'http://polar.usc.edu/12u',
#  'http://polar.usc.edu/12w',
#  'http://polar.usc.edu/12v',
#  'http://polar.usc.edu/12r',
#  'http://polar.usc.edu/12x',
#  'http://polar.usc.edu/h4',
#  'http://polar.usc.edu/h2',
#  'http://polar.usc.edu/h5',
#  'http://polar.usc.edu/h6',
#  'http://polar.usc.edu/h9',
#  'http://polar.usc.edu/h10',
#  'http://polar.usc.edu/h8',
#  'http://polar.usc.edu/h7',
#  'http://polar.usc.edu/h72',
#  'http://polar.usc.edu/h67',
#  'http://polar.usc.edu/h70',
#  'http://polar.usc.edu/h69',
#  'http://polar.usc.edu/h71',
#  'http://polar.usc.edu/h73',
#  'http://polar.usc.edu/h65',
#  'http://polar.usc.edu/h66',
#  'http://polar.usc.edu/h68',
#  'http://polar.usc.edu/h114',
#  'http://polar.usc.edu/h113',
#  'http://polar.usc.edu/h111',
#  'http://polar.usc.edu/h116',
#  'http://polar.usc.edu/h117',
#  'http://polar.usc.edu/h112',
#  'http://polar.usc.edu/h118',
#  'http://polar.usc.edu/h110',
#  'http://polar.usc.edu/h115',
#  'http://polar.usc.edu/h123',
#  'http://polar.usc.edu/h121',
#  'http://polar.usc.edu/h119',
#  'http://polar.usc.edu/h125',
#  'http://polar.usc.edu/h122',
#  'http://polar.usc.edu/h127',
#  'http://polar.usc.edu/h120',
#  'http://polar.usc.edu/h124',
#  'http://polar.usc.edu/h126',
#  'http://polar.usc.edu/hh770',
#  'http://polar.usc.edu/hh773',
#  'http://polar.usc.edu/hh772',
#  'http://polar.usc.edu/hh775',
#  'http://polar.usc.edu/hh776',
#  'http://polar.usc.edu/hh799',
#  'http://polar.usc.edu/hh797',
#  'http://polar.usc.edu/hh803',
#  'http://polar.usc.edu/hh804',
#  'http://polar.usc.edu/hh805',
#  'http://polar.usc.edu/hh802',
#  'http://polar.usc.edu/hh801',
#  'http://polar.usc.edu/hh798',
#  'http://polar.usc.edu/hh826',
#  'http://polar.usc.edu/hh824',
#  'http://polar.usc.edu/hh825',
#  'http://polar.usc.edu/hh827',
#  'http://polar.usc.edu/hh828',
#  'http://polar.usc.edu/hh832',
#  'http://polar.usc.edu/hh831',
#  'http://polar.usc.edu/hh858',
#  'http://polar.usc.edu/hh853',
#  'http://polar.usc.edu/hh854',
#  'http://polar.usc.edu/hh857',
#  'http://polar.usc.edu/hh855',
#  'http://polar.usc.edu/hh886',
#  'http://polar.usc.edu/hh878',
#  'http://polar.usc.edu/hh880',
#  'http://polar.usc.edu/hh884',
#  'http://polar.usc.edu/hh882',
#  'http://polar.usc.edu/hh908',
#  'http://polar.usc.edu/hh906',
#  'http://polar.usc.edu/hh910',
#  'http://polar.usc.edu/hh913',
#  'http://polar.usc.edu/hh912',
#  'http://polar.usc.edu/hh909',
#  'http://polar.usc.edu/hh907',
#  'http://polar.usc.edu/hh940',
#  'http://polar.usc.edu/hh937',
#  'http://polar.usc.edu/hh933',
#  'http://polar.usc.edu/hh932',
#  'http://polar.usc.edu/hh935',
#  'http://polar.usc.edu/hh934',
#  'http://polar.usc.edu/hh936',
#  'http://polar.usc.edu/hh952',
#  'http://polar.usc.edu/hh953',
#  'http://polar.usc.edu/hh951',
#  'http://polar.usc.edu/hh954',
#  'http://polar.usc.edu/hh950',
#  'http://polar.usc.edu/hh955',
#  'http://polar.usc.edu/hh957',
#  'http://polar.usc.edu/hh987',
#  'http://polar.usc.edu/hh994',
#  'http://polar.usc.edu/hh991',
#  'http://polar.usc.edu/hh986',
#  'http://polar.usc.edu/hh992',
#  'http://polar.usc.edu/hh990',
#  'http://polar.usc.edu/hh989',
#  'http://polar.usc.edu/hh988',
#  'http://polar.usc.edu/hh1019',
#  'http://polar.usc.edu/hh1017',
#  'http://polar.usc.edu/hh1015',
#  'http://polar.usc.edu/hh1021',
#  'http://polar.usc.edu/hh1018',
#  'http://polar.usc.edu/hh1016',
#  'http://polar.usc.edu/hh1020',
#  'http://polar.usc.edu/hh1013',
#  'http://polar.usc.edu/hh1014',
#  'http://polar.usc.edu/hh1050',
#  'http://polar.usc.edu/hh1054',
#  'http://polar.usc.edu/hh1055',
#  'http://polar.usc.edu/hh1053',
#  'http://polar.usc.edu/hh1051',
#  'http://polar.usc.edu/hh1081',
#  'http://polar.usc.edu/hh1082',
#  'http://polar.usc.edu/hh1084',
#  'http://polar.usc.edu/hh1078',
#  'http://polar.usc.edu/hh1079',
#  'http://polar.usc.edu/hh1086',
#  'http://polar.usc.edu/hh1089',
#  'http://polar.usc.edu/hh1092',
#  'http://polar.usc.edu/hh1087',
#  'http://polar.usc.edu/hh1093',
#  'http://polar.usc.edu/hh1085',
#  'http://polar.usc.edu/hh1090',
#  'http://polar.usc.edu/hh1116',
#  'http://polar.usc.edu/hh1117',
#  'http://polar.usc.edu/hh1114',
#  'http://polar.usc.edu/hh1115',
#  'http://polar.usc.edu/hh1120',
#  'http://polar.usc.edu/hh1112',
#  'http://polar.usc.edu/hh1118',
#  'http://polar.usc.edu/hh1148',
#  'http://polar.usc.edu/hh1150',
#  'http://polar.usc.edu/hh1151',
#  'http://polar.usc.edu/hh1152',
#  'http://polar.usc.edu/hh1156',
#  'http://polar.usc.edu/hh1154',
#  'http://polar.usc.edu/hh1155',
#  'http://polar.usc.edu/hh1153',
#  'http://polar.usc.edu/hh1167',
#  'http://polar.usc.edu/hh1169',
#  'http://polar.usc.edu/hh1168',
#  'http://polar.usc.edu/hh1166',
#  'http://polar.usc.edu/hh1172',
#  'http://polar.usc.edu/hh1171',
#  'http://polar.usc.edu/hh1174',
#  'http://polar.usc.edu/hh1191',
#  'http://polar.usc.edu/hh1190',
#  'http://polar.usc.edu/hh1184',
#  'http://polar.usc.edu/hh1185',
#  'http://polar.usc.edu/hh1188',
#  'http://polar.usc.edu/hh1192',
#  'http://polar.usc.edu/hh1186',
#  'http://polar.usc.edu/hh1189',
#  'http://polar.usc.edu/hh1214',
#  'http://polar.usc.edu/hh1215',
#  'http://polar.usc.edu/hh1212',
#  'http://polar.usc.edu/hh1219',
#  'http://polar.usc.edu/hh1213',
#  'http://polar.usc.edu/hh1218',
#  'http://polar.usc.edu/hh1216',
#  'http://polar.usc.edu/hh1217',
#  'http://polar.usc.edu/hh1211',
#  'http://polar.usc.edu/hh1256',
#  'http://polar.usc.edu/hh1258',
#  'http://polar.usc.edu/hh1259',
#  'http://polar.usc.edu/hh1257',
#  'http://polar.usc.edu/hh1291',
#  'http://polar.usc.edu/hh1289',
#  'http://polar.usc.edu/hh1290',
#  'http://polar.usc.edu/hh1288',
#  'http://polar.usc.edu/hh1317',
#  'http://polar.usc.edu/hh1310',
#  'http://polar.usc.edu/hh1313',
#  'http://polar.usc.edu/hh1314',
#  'http://polar.usc.edu/hh1316',
#  'http://polar.usc.edu/hh1312',
#  'http://polar.usc.edu/hh1311',
#  'http://polar.usc.edu/hh1342',
#  'http://polar.usc.edu/hh1337',
#  'http://polar.usc.edu/hh1343',
#  'http://polar.usc.edu/hh1344',
#  'http://polar.usc.edu/hh1340',
#  'http://polar.usc.edu/hh1339',
#  'http://polar.usc.edu/hh1338',
#  'http://polar.usc.edu/hh1345',
#  'http://polar.usc.edu/hh1341',
#  'http://polar.usc.edu/hh1368',
#  'http://polar.usc.edu/hh1365',
#  'http://polar.usc.edu/hh1366',
#  'http://polar.usc.edu/hh1364',
#  'http://polar.usc.edu/hh1369',
#  'http://polar.usc.edu/hh1371',
#  'http://polar.usc.edu/hh1372',
#  'http://polar.usc.edu/hh1367',
#  'http://polar.usc.edu/hh1370',
#  'http://polar.usc.edu/hh1389',
#  'http://polar.usc.edu/hh1382',
#  'http://polar.usc.edu/hh1390',
#  'http://polar.usc.edu/hh1385',
#  'http://polar.usc.edu/hh1383',
#  'http://polar.usc.edu/hh1387',
#  'http://polar.usc.edu/hh1384',
#  'http://polar.usc.edu/hh1388',
#  'http://polar.usc.edu/hh1386',
#  'http://polar.usc.edu/hh1410',
#  'http://polar.usc.edu/hh1409',
#  'http://polar.usc.edu/hh1416',
#  'http://polar.usc.edu/hh1415',
#  'http://polar.usc.edu/hh1413',
#  'http://polar.usc.edu/hh1412',
#  'http://polar.usc.edu/hh1417',
#  'http://polar.usc.edu/hh1411',
#  'http://polar.usc.edu/hh1414',
#  'http://polar.usc.edu/hh1440',
#  'http://polar.usc.edu/hh1436',
#  'http://polar.usc.edu/hh1441',
#  'http://polar.usc.edu/hh1437',
#  'http://polar.usc.edu/hh1443',
#  'http://polar.usc.edu/hh1439',
#  'http://polar.usc.edu/hh1442',
#  'http://polar.usc.edu/hh1444',
#  'http://polar.usc.edu/hh1438',
#  'http://polar.usc.edu/hh1466',
#  'http://polar.usc.edu/hh1467',
#  'http://polar.usc.edu/hh1468',
#  'http://polar.usc.edu/hh1469',
#  'http://polar.usc.edu/hh1471',
#  'http://polar.usc.edu/hh1463',
#  'http://polar.usc.edu/hh1464',
#  'http://polar.usc.edu/hh1470',
#  'http://polar.usc.edu/hh1465',
#  'http://polar.usc.edu/hh1486',
#  'http://polar.usc.edu/hh1485',
#  'http://polar.usc.edu/hh1481',
#  'http://polar.usc.edu/hh1489',
#  'http://polar.usc.edu/hh1483',
#  'http://polar.usc.edu/hh1487',
#  'http://polar.usc.edu/hh1488',
#  'http://polar.usc.edu/hh1482',
#  'http://polar.usc.edu/hh1484',
#  'http://polar.usc.edu/hh1509',
#  'http://polar.usc.edu/hh1508',
#  'http://polar.usc.edu/hh1510',
#  'http://polar.usc.edu/hh1514',
#  'http://polar.usc.edu/hh1515',
#  'http://polar.usc.edu/hh1513',
#  'http://polar.usc.edu/hh1511',
#  'http://polar.usc.edu/hh1512',
#  'http://polar.usc.edu/hh1516',
#  'http://polar.usc.edu/hh1550',
#  'http://polar.usc.edu/hh1546',
#  'http://polar.usc.edu/hh1548',
#  'http://polar.usc.edu/hh1545',
#  'http://polar.usc.edu/hh1552',
#  'http://polar.usc.edu/hh1549',
#  'http://polar.usc.edu/hh1551',
#  'http://polar.usc.edu/hh1544',
#  'http://polar.usc.edu/hh1547',
#  'http://polar.usc.edu/hh1575',
#  'http://polar.usc.edu/hh1574',
#  'http://polar.usc.edu/hh1578',
#  'http://polar.usc.edu/hh1573',
#  'http://polar.usc.edu/hh1571',
#  'http://polar.usc.edu/hh1572',
#  'http://polar.usc.edu/hh1579',
#  'http://polar.usc.edu/hh1576',
#  'http://polar.usc.edu/hh1577',
#  'http://polar.usc.edu/hh760',
#  'http://polar.usc.edu/hh757',
#  'http://polar.usc.edu/hh785',
#  'http://polar.usc.edu/hh786',
#  'http://polar.usc.edu/hh809',
#  'http://polar.usc.edu/hh811',
#  'http://polar.usc.edu/hh808',
#  'http://polar.usc.edu/hh813',
#  'http://polar.usc.edu/hh807',
#  'http://polar.usc.edu/hh812',
#  'http://polar.usc.edu/hh834',
#  'http://polar.usc.edu/hh836',
#  'http://polar.usc.edu/hh837',
#  'http://polar.usc.edu/hh838',
#  'http://polar.usc.edu/hh835',
#  'http://polar.usc.edu/hh833',
#  'http://polar.usc.edu/hh866',
#  'http://polar.usc.edu/hh861',
#  'http://polar.usc.edu/hh868',
#  'http://polar.usc.edu/hh864',
#  'http://polar.usc.edu/hh865',
#  'http://polar.usc.edu/hh863',
#  'http://polar.usc.edu/hh890',
#  'http://polar.usc.edu/hh894',
#  'http://polar.usc.edu/hh889',
#  'http://polar.usc.edu/hh888',
#  'http://polar.usc.edu/hh891',
#  'http://polar.usc.edu/hh887',
#  'http://polar.usc.edu/hh893',
#  'http://polar.usc.edu/hh918',
#  'http://polar.usc.edu/hh920',
#  'http://polar.usc.edu/hh919',
#  'http://polar.usc.edu/hh916',
#  'http://polar.usc.edu/hh922',
#  'http://polar.usc.edu/hh941',
#  ...]

# %%
n = len(all_ids)
entities_to_examine = [x for x in pd.DataFrame(most_common_entities)[0]]
m = len(entities_to_examine)
output_DB1 = np.zeros((n,m))

# %%
counter = 0
list = []
for col in range(0, 10):
    for row in range(0,n):
        counter += 1
        if counter%1000==0:
            print(counter)
        current_id = all_ids[row]
        current_NER_string = entities_to_examine[col]
        does_the_ner_show_up = does_this_url_have_this_ner(current_id, current_NER_string, ner_result_lists)
        list += ["{\"source\":"+ current_id +",\"target\":"+ current_NER_string +",\"weight\":" + str(does_the_ner_show_up+0) + "}"]
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000

# %%
list[4000]
# Out:
# 'http://polar.usc.edu/hh4320150'

# %%
pd.DataFrame(output_DB1).to_json("quick.json")
